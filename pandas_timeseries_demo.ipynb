# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from datetime import datetime

# %%
path = "/Volumes/MacintoshHD2/Users/haroonr/Detailed_datasets/Dataport/mix_homes/default_3months/101.csv"
df = pd.read_csv(path)

# %%
df[[0]] = pd.to_datetime(df["localminute"])

# %%
fig = plt.figure(figsize=(12,8))
ax=fig.add_subplot(111)
#ax.plot(df['localminute'],df['drye1'])
#df.plot('localminute','drye1')
df.plot()

# %%
df.index
# Out:
# RangeIndex(start=0, stop=126720, step=1)
